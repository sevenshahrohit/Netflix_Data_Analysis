# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('netflix_titles.csv')

# %% [markdown]
# Getting some basic information about dataset

# %% [markdown]
# 1. head
# 2. tail
# 3. shape
# 4. size
# 5. columns
# 6. dtypes
# 7. info

# %%
data.head()
data.tail()
data.shape
data.size
data.columns
data.dtypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Task 1: Is there is any duplicate record present? If yes, remove the same

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# Task 2: Is there is any null value present in any column? show with heat map.

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Q1. For 'House of Cards', what is the show id & who is the director of show?

# %%
data[data['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
data[data['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# Q2: In which year highest number of tv shows & movies were released? show with bar graph

# %%
data['movie_year']=pd.to_datetime(data['release_year'])

# %%
data['movie_year'].value_counts()
data['movie_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Q3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data['type'].value_counts()
data['type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Q4. Show all the Movies that were released in year 2000

# %%
data[(data['type']=='Movie')& (data['release_year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
data.head()
data[(data['type']=='TV Show') & (data['country']=='India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# Q6. Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
data.head()
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
 data[(data['type']=='Movie') & (data['listed_in']=='Comedies') | (data['country']=='United Kingdom')]

# %% [markdown]
# Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
data_new=data.dropna()
data_new[data_new['cast'].str.contains('Tom Cruise')]

# %% [markdown]
# Q. 9) What are the different Ratings defined by Netflix ?

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q10) How many Movies got the 'TV-14' rating, in Canada ?

# %%
data[(data['rating']=='TV-14') & (data['country']=='Canada') & (data['type']=='Movie')].shape[0]
# Out:
# 13

# %% [markdown]
#     Q11) How many TV Shows got the 'TV-MA' rating, after year 2018 ?

# %%
data[(data['type']=='TV Show') & (data['rating']=='TV-MA') & (data['release_year']>2018)].shape[0]
# Out:
# 623

# %% [markdown]
# Q12) What is the maximum duration of a Movie/Show on Netflix ?

# %%
data[['Number','Unit']]= data['duration'].str.split(' ', expand=True)
data['Number']=pd.to_numeric(data['Number'])
data['Number'].max()
# Out:
# 312.0

# %% [markdown]
# Q13. Which country has highest number of TV Shows?

# %%
data_tv=data[data['type']=='TV Show']

data_tv['country'].value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# Q14. How can we sort dataset by Year?

# %%
data.sort_values(by='release_year', ascending=False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %% [markdown]
# Q15. Find all instance where :
#     Type is Movie and listed_in is dramas
#     or
#     type is tv show and listed_in is kids tv

# %%
data[(data['type']==('Movie')) & (data['listed_in']==('Dramas')) |
     (data['type']==('TV Show')) & (data['listed_in']==("Kids' TV"))
    ]
# Out:
#      show_id     type                    title          director  \
# 34       s35  TV Show  Tayo and Little Wizards               NaN
# 39       s40  TV Show             Chhota Bheem               NaN
# 65       s66  TV Show             Numberblocks               NaN
# 89       s90  TV Show              Mighty Raju               NaN
# 100     s101  TV Show  Tobot Galaxy Detectives               NaN
# ...      ...      ...                      ...               ...
# 8691   s8692    Movie                Wakefield     Robin Swicord
# 8696   s8697    Movie                War Horse  Steven Spielberg
# 8783   s8784  TV Show                     Yoko               NaN
# 8785   s8786  TV Show                      YOM               NaN
# 8797   s8798  TV Show                Zak Storm               NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# ...
